# %% [markdown]
# # PostgreSQL CRUD Simulations
#
# ## 🐘 Complete PostgreSQL CRUD Simulations Operations
#
# This notebook demonstrates all possible PostgreSQL CRUD Simulations features including:
# - Basic CRUD operations
# - Advanced SQL features
# - Special database features
# - Performance optimizations
# - AI and Vector extensions (where applicable)

# %%
# Install required packages
# !pip install psycopg2-binary sqlalchemy pandas numpy

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import json

# Connection parameters
DB_CONFIG = {
    "host": "localhost",
    "port": 5432,
    "database": "ai_valido_online",
    "user": "postgres",
    "password": "postgres"
}

def connect_postgresql():
    """Connect to PostgreSQL database"""
    try:
        import psycopg2
        conn = psycopg2.connect(**DB_CONFIG)
        print("✅ Connected to PostgreSQL successfully!")
        return conn
    except Exception as e:
        print(f"❌ Connection failed: {e}")
        return None

def list_databases(conn):
    """List all databases"""
    cursor = conn.cursor()
    cursor.execute("SELECT datname FROM pg_database WHERE datistemplate = false;")
    databases = cursor.fetchall()
    cursor.close()
    return [db[0] for db in databases]

def list_tables(conn):
    """List all tables in current database"""
    cursor = conn.cursor()
    cursor.execute("""
        SELECT table_name 
        FROM information_schema.tables 
        WHERE table_schema = 'public'
        ORDER BY table_name;
    """)
    tables = cursor.fetchall()
    cursor.close()
    return [table[0] for table in tables]

def list_extensions(conn):
    """List all installed extensions"""
    cursor = conn.cursor()
    cursor.execute("SELECT extname FROM pg_extension;")
    extensions = cursor.fetchall()
    cursor.close()
    return [ext[0] for ext in extensions]

# Test connection
conn = connect_postgresql()
if conn:
    print(f"\n📊 Databases: {list_databases(conn)}")
    print(f"📋 Tables: {list_tables(conn)}")
    print(f"🔧 Extensions: {list_extensions(conn)}")

# %%
# Database Information Functions
def list_functions(conn):
    """List all functions"""
    cursor = conn.cursor()
    cursor.execute("""
        SELECT routine_name 
        FROM information_schema.routines 
        WHERE routine_schema = 'public'
        ORDER BY routine_name;
    """)
    functions = cursor.fetchall()
    cursor.close()
    return [func[0] for func in functions]

def list_views(conn):
    """List all views"""
    cursor = conn.cursor()
    cursor.execute("""
        SELECT table_name 
        FROM information_schema.views 
        WHERE table_schema = 'public'
        ORDER BY table_name;
    """)
    views = cursor.fetchall()
    cursor.close()
    return [view[0] for view in views]

if conn:
    print(f"🔧 Functions: {list_functions(conn)}")
    print(f"👁️ Views: {list_views(conn)}")

# %%
# Basic CRUD Operations
# TODO: Add specific CRUD operations for this database type
