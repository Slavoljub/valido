# %%
import pandas as pd

# Učitavanje domaćih podataka
domaci = pd.read_csv('../data/domaci.csv')  # Proveri putanju do fajla
print("Prvih nekoliko redova iz domaci.csv:")
print(domaci.head())

# Učitavanje podataka o izvozu
izvoz = pd.read_csv('../data/izvoz.csv')  # Proveri putanju do fajla
print("\nPrvih nekoliko redova iz izvoz.csv:")
print(izvoz.head())

# Prikaz svih kolona iz oba fajla
print("\nKolone u domaci.csv:", domaci.columns)
print("Kolone u izvoz.csv:", izvoz.columns)
# Out:
# Prvih nekoliko redova iz domaci.csv:
#    Broj  Poreski Period Broj Fakture Datum Knjizenja       Mesto  \
# 0   1.0             5.0            1      2024-05-07  Kragujevac
# 1   2.0             5.0            2      2024-05-13     STOJNIK
# 2   3.0             5.0            3      2024-05-13     STOJNIK
# 3   4.0             5.0            4      2024-05-11  Kragujevac
# 4   5.0             5.0            5      2024-05-20  Kragujevac
#
#    Poresko Oslobodjenje  Osnovica Opsta Stopa  Porez Opsta Stopa  \
# 0                     0              115680.0            23136.0
# 1                     0               39120.0             7824.0
# 2                     0              235200.0            47040.0
# 3                     0                4760.0              952.0
# 4                     0               36000.0             7200.0
#
#    Ukupno Bez PDV-a
# 0          115680.0
# 1           39120.0
# 2          235200.0
# 3            4760.0
# 4           36000.0
#
# ...
