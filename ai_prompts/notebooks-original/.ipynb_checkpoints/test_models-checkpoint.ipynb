# %%
from models.openai_models import predict_validoai_explanation, predict_time_series_analysis

print("Funkcije uspešno uvezene!")
# Out:
# Funkcije uspešno uvezene!
