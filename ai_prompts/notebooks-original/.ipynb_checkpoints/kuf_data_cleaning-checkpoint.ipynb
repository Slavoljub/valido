# %%
import pandas as pd

# 1. Učitavanje podataka iz CSV fajla
# Komentar: Ova funkcija čita sirove podatke kako bismo ih mogli obraditi.
ile_path = '/home/malac/Desktop/MIT/projekat/validoAI/data/danego_plus/kuf_csv/ocisceni/danego_ocisceni_kuf.csv'
kuf_data = pd.read_csv(file_path)

# Preimenovanje kolona
kuf_data.rename(columns={
    'datdok': 'Datum',
    'nazivkupca': 'Dobavljač',
    'Ukupno sa pdv': 'UkupnoSaPDVom'
}, inplace=True)

# Filtriranje relevantnih kolona
filtered_kuf_data = kuf_data[['Datum', 'Dobavljač', 'UkupnoSaPDVom']]

# Prikazivanje svih redova iz filtriranih podataka
print(filtered_kuf_data.to_string())  # Prikaz svih redova bez skraćivanja
# Out:
#           Datum                       Dobavljač  UkupnoSaPDVom
# 0    24/05/2024                METRO KRAGUJEVAC       38608.48
# 1    24/05/2024                METRO KRAGUJEVAC         274.38
# 2    10/05/2024                METRO KRAGUJEVAC       45371.56
# 3    10/05/2024                METRO KRAGUJEVAC         905.10
# 4    10/05/2024                METRO KRAGUJEVAC       24609.75
# 5    06/05/2024                METRO KRAGUJEVAC        8879.64
# 6    03/05/2024                METRO KRAGUJEVAC        4882.51
# 7    03/05/2024                METRO KRAGUJEVAC       20000.22
# 8    16/05/2024                METRO KRAGUJEVAC       84392.42
# 9    20/05/2024                METRO KRAGUJEVAC       57679.56
# 10   20/05/2024                METRO KRAGUJEVAC         548.76
# 11   21/05/2024                METRO KRAGUJEVAC        8075.00
# 12   01/05/2024                  EPS AD BEOGRAD       24388.54
# 13   01/05/2024                  EPS AD BEOGRAD         299.00
# ...
