# %%
import pandas as pd
from IPython.display import display
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="matplotlib")

# 1. Učitavanje podataka
domaci = pd.read_csv('../../data/mom21/promet/domaci.csv')

# 2. Odabir ključnih kolona
domaci_cleaned = domaci[['Datum Knjizenja', 'Mesto', 'Osnovica Opsta Stopa', 'Porez Opsta Stopa', 'Ukupno Bez PDV-a']].copy()

# 3. Dodavanje kolone za prihode
domaci_cleaned['Prihodi'] = domaci_cleaned['Osnovica Opsta Stopa'] + domaci_cleaned['Porez Opsta Stopa']

# 4. Zaokruživanje float vrednosti
pd.options.display.float_format = '{:.2f}'.format

# Prikaz celog DataFrame-a sa stilizacijom
display(domaci.style.set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '12pt'), ('text-align', 'center')]},
     {'selector': 'td', 'props': [('font-size', '10pt'), ('text-align', 'center')]}]
).set_properties(**{'border': '1px solid black'}))
# Out:
# <style type="text/css">
# #T_b0540 th {
#   font-size: 12pt;
#   text-align: center;
# }
# #T_b0540 td {
#   font-size: 10pt;
#   text-align: center;
# }
# #T_b0540_row0_col0, #T_b0540_row0_col1, #T_b0540_row0_col2, #T_b0540_row0_col3, #T_b0540_row0_col4, #T_b0540_row0_col5, #T_b0540_row0_col6, #T_b0540_row0_col7, #T_b0540_row1_col0, #T_b0540_row1_col1, #T_b0540_row1_col2, #T_b0540_row1_col3, #T_b0540_row1_col4, #T_b0540_row1_col5, #T_b0540_row1_col6, #T_b0540_row1_col7, #T_b0540_row2_col0, #T_b0540_row2_col1, #T_b0540_row2_col2, #T_b0540_row2_col3, #T_b0540_row2_col4, #T_b0540_row2_col5, #T_b0540_row2_col6, #T_b0540_row2_col7, #T_b0540_row3_col0, #T_b0540_row3_col1, #T_b0540_row3_col2, #T_b0540_row3_col3, #T_b0540_row3_col4, #T_b0540_row3_col5, #T_b0540_row3_col6, #T_b0540_row3_col7, #T_b0540_row4_col0, #T_b0540_row4_col1, #T_b0540_row4_col2, #T_b0540_row4_col3, #T_b0540_row4_col4, #T_b0540_row4_col5, #T_b0540_row4_col6, #T_b0540_row4_col7, #T_b0540_row5_col0, #T_b0540_row5_col1, #T_b0540_row5_col2, #T_b0540_row5_col3, #T_b0540_row5_col4, #T_b0540_row5_col5, #T_b0540_row5_col6, #T_b0540_row5_col7, #T_b0540_row6_col0, #T_b0540_row6_col1, #T_b0540_row6_col2, #T_b0540_row6_col3, #T_b0540_row6_col4, #T_b0540_row6_col5, #T_b0540_row6_col6, #T_b0540_row6_col7, #T_b0540_row7_col0, #T_b0540_row7_col1, #T_b0540_row7_col2, #T_b0540_row7_col3, #T_b0540_row7_col4, #T_b0540_row7_col5, #T_b0540_row7_col6, #T_b0540_row7_col7, #T_b0540_row8_col0, #T_b0540_row8_col1, #T_b0540_row8_col2, #T_b0540_row8_col3, #T_b0540_row8_col4, #T_b0540_row8_col5, #T_b0540_row8_col6, #T_b0540_row8_col7, #T_b0540_row9_col0, #T_b0540_row9_col1, #T_b0540_row9_col2, #T_b0540_row9_col3, #T_b0540_row9_col4, #T_b0540_row9_col5, #T_b0540_row9_col6, #T_b0540_row9_col7, #T_b0540_row10_col0, #T_b0540_row10_col1, #T_b0540_row10_col2, #T_b0540_row10_col3, #T_b0540_row10_col4, #T_b0540_row10_col5, #T_b0540_row10_col6, #T_b0540_row10_col7, #T_b0540_row11_col0, #T_b0540_row11_col1, #T_b0540_row11_col2, #T_b0540_row11_col3, #T_b0540_row11_col4, #T_b0540_row11_col5, #T_b0540_row11_col6, #T_b0540_row11_col7, #T_b0540_row12_col0, #T_b0540_row12_col1, #T_b0540_row12_col2, #T_b0540_row12_col3, #T_b0540_row12_col4, #T_b0540_row12_col5, #T_b0540_row12_col6, #T_b0540_row12_col7, #T_b0540_row13_col0, #T_b0540_row13_col1, #T_b0540_row13_col2, #T_b0540_row13_col3, #T_b0540_row13_col4, #T_b0540_row13_col5, #T_b0540_row13_col6, #T_b0540_row13_col7, #T_b0540_row14_col0, #T_b0540_row14_col1, #T_b0540_row14_col2, #T_b0540_row14_col3, #T_b0540_row14_col4, #T_b0540_row14_col5, #T_b0540_row14_col6, #T_b0540_row14_col7, #T_b0540_row15_col0, #T_b0540_row15_col1, #T_b0540_row15_col2, #T_b0540_row15_col3, #T_b0540_row15_col4, #T_b0540_row15_col5, #T_b0540_row15_col6, #T_b0540_row15_col7, #T_b0540_row16_col0, #T_b0540_row16_col1, #T_b0540_row16_col2, #T_b0540_row16_col3, #T_b0540_row16_col4, #T_b0540_row16_col5, #T_b0540_row16_col6, #T_b0540_row16_col7, #T_b0540_row17_col0, #T_b0540_row17_col1, #T_b0540_row17_col2, #T_b0540_row17_col3, #T_b0540_row17_col4, #T_b0540_row17_col5, #T_b0540_row17_col6, #T_b0540_row17_col7, #T_b0540_row18_col0, #T_b0540_row18_col1, #T_b0540_row18_col2, #T_b0540_row18_col3, #T_b0540_row18_col4, #T_b0540_row18_col5, #T_b0540_row18_col6, #T_b0540_row18_col7, #T_b0540_row19_col0, #T_b0540_row19_col1, #T_b0540_row19_col2, #T_b0540_row19_col3, #T_b0540_row19_col4, #T_b0540_row19_col5, #T_b0540_row19_col6, #T_b0540_row19_col7, #T_b0540_row20_col0, #T_b0540_row20_col1, #T_b0540_row20_col2, #T_b0540_row20_col3, #T_b0540_row20_col4, #T_b0540_row20_col5, #T_b0540_row20_col6, #T_b0540_row20_col7, #T_b0540_row21_col0, #T_b0540_row21_col1, #T_b0540_row21_col2, #T_b0540_row21_col3, #T_b0540_row21_col4, #T_b0540_row21_col5, #T_b0540_row21_col6, #T_b0540_row21_col7, #T_b0540_row22_col0, #T_b0540_row22_col1, #T_b0540_row22_col2, #T_b0540_row22_col3, #T_b0540_row22_col4, #T_b0540_row22_col5, #T_b0540_row22_col6, #T_b0540_row22_col7, #T_b0540_row23_col0, #T_b0540_row23_col1, #T_b0540_row23_col2, #T_b0540_row23_col3, #T_b0540_row23_col4, #T_b0540_row23_col5, #T_b0540_row23_col6, #T_b0540_row23_col7, #T_b0540_row24_col0, #T_b0540_row24_col1, #T_b05 ...

# %%
# 1. Učitavanje podataka iz prvog fajla (domaci.csv)
# Ove podatke želimo da formatiramo prema šablonu (drugom fajlu).
import pandas as pd
domaci = pd.read_csv('../../data/mom21/promet/domaci.csv')

# 2. Definisanje funkcije za formatiranje
# Ova funkcija kreira tekstualni opis jednog reda na osnovu šablona drugog fajla.
def formatiraj_red(row):
    # Pravimo formatirani tekst koristeći podatke iz `domaci`
    # Ovaj format je samo primer i treba da odgovara šablonu drugog fajla
    return (
        f"Dokument {row['Datum Knjizenja']} iz {row['Mesto']} "
        f"ima osnovicu od {row['Osnovica Opsta Stopa']} RSD, "
        f"sa porezom od {row['Porez Opsta Stopa']} RSD. "
        f"Ukupno bez PDV-a: {row['Ukupno Bez PDV-a']} RSD."
    )

# 3. Kreiranje tekstualnih opisa za svaki red
# Iteriramo kroz sve redove `domaci` i formatiramo podatke koristeći funkciju `formatiraj_red`.
tekstualni_opisi = [formatiraj_red(row) for _, row in domaci.iterrows()]

# 4. Čuvanje tekstualnih opisa u fajl
# Rezultat snimamo kao tekstualni fajl za dalje korišćenje.
output_path = "../../data/mom21/txt/domaci_formatirani_opisi.txt"
with open(output_path, 'w', encoding='utf-8') as f:
    # Spajamo sve opise u jedan string, svaki red ide u novi red fajla.
    f.write('\n'.join(tekstualni_opisi))

# Obaveštavamo korisnika o uspešnom čuvanju fajla
print(f"Formatirani tekstualni opisi su sačuvani u {output_path}")

# Prikazujemo sve tekstualne opise.
for opis in tekstualni_opisi:
    print(opis)
# Out:
# Formatirani tekstualni opisi su sačuvani u ../../data/mom21/txt/domaci_formatirani_opisi.txt
# Dokument 2024-05-07 iz Kragujevac ima osnovicu od 115680.0 RSD, sa porezom od 23136.0 RSD. Ukupno bez PDV-a: 115680.0 RSD.
# Dokument 2024-05-13 iz STOJNIK ima osnovicu od 39120.0 RSD, sa porezom od 7824.0 RSD. Ukupno bez PDV-a: 39120.0 RSD.
# Dokument 2024-05-13 iz STOJNIK ima osnovicu od 235200.0 RSD, sa porezom od 47040.0 RSD. Ukupno bez PDV-a: 235200.0 RSD.
# Dokument 2024-05-11 iz Kragujevac ima osnovicu od 4760.0 RSD, sa porezom od 952.0 RSD. Ukupno bez PDV-a: 4760.0 RSD.
# Dokument 2024-05-20 iz Kragujevac ima osnovicu od 36000.0 RSD, sa porezom od 7200.0 RSD. Ukupno bez PDV-a: 36000.0 RSD.
# Dokument 2024-05-22 iz Kragujevac ima osnovicu od 27520.0 RSD, sa porezom od 5504.0 RSD. Ukupno bez PDV-a: 27520.0 RSD.
# Dokument 2024-05-23 iz Kragujevac ima osnovicu od 40800.0 RSD, sa porezom od 8160.0 RSD. Ukupno bez PDV-a: 40800.0 RSD.
# Dokument 2024-05-28 iz Kragujevac ima osnovicu od 17600.0 RSD, sa porezom od 3520.0 RSD. Ukupno bez PDV-a: 17600.0 RSD.
# Dokument 2024-05-31 iz KRAGUJEVAC ima osnovicu od 17400.0 RSD, sa porezom od 3480.0 RSD. Ukupno bez PDV-a: 17400.0 RSD.
# Dokument 2024-05-02 iz STOJNIK ima osnovicu od 109710.0 RSD, sa porezom od 21942.0 RSD. Ukupno bez PDV-a: 109710.0 RSD.
# Dokument 2024-05-22 iz STOJNIK ima osnovicu od 13400.0 RSD, sa porezom od 2680.0 RSD. Ukupno bez PDV-a: 13400.0 RSD.
# Dokument 2024-05-22 iz STOJNIK ima osnovicu od 11800.0 RSD, sa porezom od 2360.0 RSD. Ukupno bez PDV-a: 11800.0 RSD.
# Dokument 2024-05-22 iz STOJNIK ima osnovicu od 47650.0 RSD, sa porezom od 9530.0 RSD. Ukupno bez PDV-a: 47650.0 RSD.
# Dokument nan iz nan ima osnovicu od 716640.0 RSD, sa porezom od 143328.0 RSD. Ukupno bez PDV-a: 716640.0 RSD.
# Dokument 2024-06-04 iz STOJNIK ima osnovicu od 5850.0 RSD, sa porezom od 1170.0 RSD. Ukupno bez PDV-a: 5850.0 RSD.
# Dokument 2024-06-04 iz KRAGUJEVAC ima osnovicu od 3080.0 RSD, sa porezom od 616.0 RSD. Ukupno bez PDV-a: 3080.0 RSD.
# Dokument 2024-06-05 iz KRAGUJEVAC ima osnovicu od 33900.0 RSD, sa porezom od 6780.0 RSD. Ukupno bez PDV-a: 33900.0 RSD.
# Dokument 2024-06-05 iz GORNJI MILANOVAC ima osnovicu od 22500.0 RSD, sa porezom od 4500.0 RSD. Ukupno bez PDV-a: 22500.0 RSD.
# Dokument 2024-06-10 iz Kragujevac ima osnovicu od 4760.0 RSD, sa porezom od 952.0 RSD. Ukupno bez PDV-a: 4760.0 RSD.
# Dokument 2024-06-17 iz KRAGUJEVAC ima osnovicu od 25600.0 RSD, sa porezom od 5120.0 RSD. Ukupno bez PDV-a: 25600.0 RSD.
# Dokument 2024-06-17 iz BATOCINA ima osnovicu od 46800.0 RSD, sa porezom od 9360.0 RSD. Ukupno bez PDV-a: 46800.0 RSD.
# Dokument 2024-06-21 iz BEOGRAD ima osnovicu od 43280.0 RSD, sa porezom od 8656.0 RSD. Ukupno bez PDV-a: 43280.0 RSD.
# Dokument 2024-06-30 iz KRAGUJEVAC ima osnovicu od 0.0 RSD, sa porezom od 0.0 RSD. Ukupno bez PDV-a: 9800.0 RSD.
# Dokument nan iz nan ima osnovicu od 185770.0 RSD, sa porezom od 37154.0 RSD. Ukupno bez PDV-a: 195570.0 RSD.
# Dokument 2024-07-01 iz Kragujevac ima osnovicu od 64331.28 RSD, sa porezom od 12866.26 RSD. Ukupno bez PDV-a: 64331.28 RSD.
# Dokument 2024-07-01 iz Kragujevac ima osnovicu od 26676.0 RSD, sa porezom od 5335.2 RSD. Ukupno bez PDV-a: 26676.0 RSD.
# Dokument 2024-07-01 iz Kragujevac ima osnovicu od 4212.0 RSD, sa porezom od 842.4 RSD. Ukupno bez PDV-a: 4212.0 RSD.
# Dokument 2024-07-02 iz KRAGUJEVAC ima osnovicu od 107040.0 RSD, sa porezom od 21408.0 RSD. Ukupno bez PDV-a: 107040.0 RSD.
# Dokument 2024-07-02 iz KRAGUJEVAC ima osnovicu od -107040.0 RSD, sa porezom od -21408.0 RSD. Ukupno bez PDV-a: -107040.0 RSD.
# Dokument 2024-07-02 iz STOJNIK ima osnovicu od 62085.0 RSD, sa porezom od 12417.0 RSD. Ukupno bez PDV-a: 62085.0 RSD.
# Dokument 2024-07-02 iz STOJNIK ima osnovicu od 76523.0 RSD, sa porezom od 15304.6 RSD. Ukupno bez PDV-a: 76523.0 RSD.
# Dokument 2024-07-05 iz Kragujevac ima osnovicu od 4760.0 RSD, sa porezom od 952.0 RSD. Ukupno bez PDV-a: 4760.0 RSD.
# Dokument 2024-07-05 iz KRAGUJEVAC ima osnovicu od 5600.0 RSD, sa porezom od 1120.0 RSD. Ukupno bez PDV-a: 5600.0 RSD.
# Dokument 2024-07-11 iz STOJNIK ima osnovicu od 11200.0 RSD, sa porezom od 2240.0 RSD. Ukupno bez PDV-a: 11200.0 RSD.
# Dokument 2024-07-02 iz KRAGUJEVAC ima osnovicu od 27540.0 RSD, sa porezom od 5508.0 RSD. Ukupno bez PDV-a: 27540.0 RSD.
# Dokument 2024-07-02 iz KRAGUJEVAC ima osnovicu od 79500.0 RSD, sa porezom od 15900.0 RSD. Ukupno bez PDV-a: 79500.0 RSD.
# Dokument 2024-07-18 iz STOJNIK ima osnovicu od 37075.0 RSD, sa porezom od 7415.0 RSD. Ukupno bez PDV-a: 37075.0 RSD.
# Dokument 2024-07-31 iz BEOGRAD ima osnovicu od 39120.0 RSD, sa porezom od 7824.0 RSD. Ukupno bez PDV-a: 39120.0 RSD.
# Dokument nan iz nan ima osnovicu od 438622.28 RSD, sa porezom od 87724.46 RSD. Ukupno bez PDV-a: 438622.28 RSD.
# Dokument 2024-08-13 iz KRAGUJEVAC ima osnovicu od 4000.0 RSD, sa porezom od 800.0 RSD. Ukupno bez PDV-a: 4000.0 RSD.
# Dokument 2024-08-13 iz KRAGUJEVAC ima osnovicu od 9000.0 RSD, sa porezom od 1800.0 RSD. Ukupno bez PDV-a: 9000.0 RSD.
# Dokument 2024-08-13 iz GORNJI MILANOVAC ima osnovicu od 15000.0 RSD, sa porezom od 3000.0 RSD. Ukupno bez PDV-a: 15000.0 RSD.
# Dokument 2024-08-13 iz BATOCINA ima osnovicu od 33800.0 RSD, sa porezom od 6760.0 RSD. Ukupno bez PDV-a: 33800.0 RSD.
# Dokument 2024-08-13 iz CACAK ima osnovicu od 116000.0 RSD, sa porezom od 23200.0 RSD. Ukupno bez PDV-a: 116000.0 RSD.
# Dokument 2024-08-13 iz Kragujevac ima osnovicu od 48520.8 RSD, sa porezom od 9704.16 RSD. Ukupno bez PDV-a: 48520.8 RSD.
# Dokument 2024-08-13 iz Kragujevac ima osnovicu od 47466.0 RSD, sa porezom od 9493.2 RSD. Ukupno bez PDV-a: 47466.0 RSD.
# Dokument 2024-08-21 iz CACAK ima osnovicu od 43500.0 RSD, sa porezom od 8700.0 RSD. Ukupno bez PDV-a: 43500.0 RSD.
# Dokument 2024-08-21 iz Kragujevac ima osnovicu od 23800.0 RSD, sa porezom od 4760.0 RSD. Ukupno bez PDV-a: 23800.0 RSD.
# Dokument 2024-08-27 iz KRAGUJEVAC ima osnovicu od 15100.0 RSD, sa porezom od 3020.0 RSD. Ukupno bez PDV-a: 15100.0 RSD.
# Dokument 2024-08-27 iz KRAGUJEVAC ima osnovicu od 26000.0 RSD, sa porezom od 5200.0 RSD. Ukupno bez PDV-a: 26000.0 RSD.
# Dokument 2024-08-30 iz Kragujevac ima osnovicu od 960.0 RSD, sa porezom od 192.0 RSD. Ukupno bez PDV-a: 960.0 RSD.
# Dokument nan iz nan ima osnovicu od 383146.8 RSD, sa porezom od 76629.36 RSD. Ukupno bez PDV-a: 383146.8 RSD.
# Dokument 2024-09-02 iz KRAGUJEVAC ima osnovicu od 14000.0 RSD, sa porezom od 2800.0 RSD. Ukupno bez PDV-a: 14000.0 RSD.
# Dokument 2024-09-02 iz CVETOJEVAC ima osnovicu od 56200.0 RSD, sa porezom od 11240.0 RSD. Ukupno bez PDV-a: 56200.0 RSD.
# Dokument 2024-09-02 iz STOJNIK ima osnovicu od 22208.0 RSD, sa porezom od 4441.6 RSD. Ukupno bez PDV-a: 22208.0 RSD.
# Dokument 2024-09-04 iz BEOGRAD ima osnovicu od 96000.0 RSD, sa porezom od 19200.0 RSD. Ukupno bez PDV-a: 96000.0 RSD.
# Dokument 2024-09-06 iz STOJNIK ima osnovicu od 44192.0 RSD, sa porezom od 8838.4 RSD. Ukupno bez PDV-a: 44192.0 RSD.
# Dokument 2024-09-18 iz Kragujevac ima osnovicu od 21760.0 RSD, sa porezom od 4352.0 RSD. Ukupno bez PDV-a: 21760.0 RSD.
# Dokument 2024-09-25 iz Kragujevac ima osnovicu od -21760.0 RSD, sa porezom od -4352.0 RSD. Ukupno bez PDV-a: -21760.0 RSD.
# Dokument 2024-09-16 iz KRAGUJEVAC ima osnovicu od 27000.0 RSD, sa porezom od 5400.0 RSD. Ukupno bez PDV-a: 27000.0 RSD.
# Dokument 2024-09-19 iz KRAGUJEVAC ima osnovicu od 8700.0 RSD, sa porezom od 1740.0 RSD. Ukupno bez PDV-a: 8700.0 RSD.
# Dokument 2024-09-19 iz KRAGUJEVAC ima osnovicu od 5000.0 RSD, sa porezom od 1000.0 RSD. Ukupno bez PDV-a: 5000.0 RSD.
# Dokument 2024-09-18 iz Kragujevac ima osnovicu od 11560.0 RSD, sa porezom od 2312.0 RSD. Ukupno bez PDV-a: 11560.0 RSD.
# Dokument 2024-09-25 iz Kragujevac ima osnovicu od 10200.0 RSD, sa porezom od 2040.0 RSD. Ukupno bez PDV-a: 10200.0 RSD.
# Dokument 2024-09-27 iz KRAGUJEVAC ima osnovicu od 199538.0 RSD, sa porezom od 39907.6 RSD. Ukupno bez PDV-a: 199538.0 RSD.
# Dokument nan iz nan ima osnovicu od 494598.0 RSD, sa porezom od 98919.6 RSD. Ukupno bez PDV-a: 494598.0 RSD.
# Dokument 2024-10-30 iz KRAGUJEVAC ima osnovicu od 27300.0 RSD, sa porezom od 5460.0 RSD. Ukupno bez PDV-a: 27300.0 RSD.
# Dokument 2024-10-03 iz Kragujevac ima osnovicu od 20596.0 RSD, sa porezom od 4119.2 RSD. Ukupno bez PDV-a: 20596.0 RSD.
# Dokument 2024-10-04 iz STOJNIK ima osnovicu od 85152.0 RSD, sa porezom od 17030.4 RSD. Ukupno bez PDV-a: 85152.0 RSD.
# Dokument 2024-10-08 iz GORNJI MILANOVAC ima osnovicu od 30000.0 RSD, sa porezom od 6000.0 RSD. Ukupno bez PDV-a: 30000.0 RSD.
# Dokument 2024-10-08 iz KRAGUJEVAC ima osnovicu od 28000.0 RSD, sa porezom od 5600.0 RSD. Ukupno bez PDV-a: 28000.0 RSD.
# Dokument 2024-10-22 iz Kragujevac ima osnovicu od 25040.0 RSD, sa porezom od 5008.0 RSD. Ukupno bez PDV-a: 25040.0 RSD.
# Dokument 2024-10-23 iz STOJNIK ima osnovicu od 20843.75 RSD, sa porezom od 4168.75 RSD. Ukupno bez PDV-a: 20843.75 RSD.
# Dokument 2024-10-23 iz STOJNIK ima osnovicu od 15350.0 RSD, sa porezom od 3070.0 RSD. Ukupno bez PDV-a: 15350.0 RSD.
# Dokument 2024-10-30 iz KRAGUJEVAC ima osnovicu od 28500.0 RSD, sa porezom od 5700.0 RSD. Ukupno bez PDV-a: 28500.0 RSD.
# Dokument 2024-10-30 iz KRAGUJEVAC ima osnovicu od 7500.0 RSD, sa porezom od 1500.0 RSD. Ukupno bez PDV-a: 7500.0 RSD.
# Dokument nan iz nan ima osnovicu od 288281.75 RSD, sa porezom od 57656.35 RSD. Ukupno bez PDV-a: 288281.75 RSD.

# %%
import openai

# Postavljanje API ključa
openai.api_key = "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"

# Testiranje API poziva
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "Ti si analitičar finansijskih podataka."},
        {"role": "user", "content": "Pozdrav, proveri da li API radi i odgovori jednostavno."}
    ],
    max_tokens=50
)

# Prikaz odgovora
print(response['choices'][0]['message']['content'])
# Out:
# Da, API radi.

# %%
import openai
# Postavljanje API ključa
openai.api_key = "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"

# Analiza faktura pomoću OpenAI
def analiziraj_fakturu(tekst_fakture):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Ti si analitičar faktura. Analiziraj anomalije u fakturama."},
            {"role": "user", "content": f"Analiziraj ovu fakturu i reci da li ima anomalija: {tekst_fakture}"}
        ],
        max_tokens=100,
        temperature=0.5
    )
    return response['choices'][0]['message']['content']

# Analiza prvih 5 faktura iz KUF-a
for i, opis in enumerate(tekstualni_opisi[:5]):
    print(f"\nFaktura {i+1}:")
    rezultat = analiziraj_fakturu(opis)
    print(rezultat)
# Out:
# Faktura 1:
# Na prvi pogled, izgleda da faktura nema očiglednih anomalija. Međutim, postoji nekoliko stvari koje bi mogle biti potencijalno sumnjive ili koje bi trebalo dodatno proveriti:
#
# 1. Porez od 23136.0 RSD predstavlja 20% od osnovice od 115680.0 RSD, što je u sklad
#
# Faktura 2:
# Na osnovu informacija date u fakturi, mogu primetiti jednu potencijalnu anomaliju. Ukupan iznos bez PDV-a iznosi 39120.0 RSD, što je isto kao i osnovica za obračun poreza. Ovo može biti indikacija greške u fakturisanju, jer bi osnovica za porez trebala biti veća od ukupn
#
# Faktura 3:
# Na osnovu informacija koje si naveo, mogu primetiti nekoliko potencijalnih anomalija u ovoj fakturi:
#
# 1. Porez je jednak tačno 20% od osnovice, što može biti indikacija da je računat neispravno ili da je osnovica ručno podešena kako bi rezultirala ovim iznosom poreza. Uobičaj
#
# Faktura 4:
# Na prvi pogled, ova faktura izgleda ispravno. Međutim, primetna je anomalija jer je iznos poreza jednak polovini osnovice, što nije u skladu sa standardnim stopama PDV-a. Standardna stopa PDV-a u Srbiji je 20%, što znači da bi porez trebao biti 20% od osnovice. U ovom sluč
#
# Faktura 5:
# Na prvi pogled, izgleda da postoji anomalija u ovoj fakturi. Prema informacijama koje su navedene, osnovica za obračun poreza iznosi 36000.0 RSD, a iznos poreza je 7200.0 RSD. Međutim, ukupan iznos bez PDV-a takođe iznosi 36000.0 RSD, što znač

# %%
from IPython.display import display, HTML
import ipywidgets as widgets
import openai
# Postavljanje OpenAI API ključa
openai.api_key = "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"

# Funkcija za prikaz poruka u stilizovanom chatu
def display_message(role, content):
    """Prikazuje poruku sa određenim stilom za korisnika ili ValidoAI."""
    if role == "user":
        display(HTML(f"""
        <div style="display: flex; justify-content: flex-end; margin: 10px;">
            <div style="padding: 10px; background-color: #e6f7ff; border-radius: 8px; width: auto; max-width: 60%; color: black;">
                <strong>Klijent:</strong> {content}
            </div>
        </div>
        """))
    elif role == "assistant":
        display(HTML(f"""
        <div style="display: flex; justify-content: flex-start; margin: 10px;">
            <div style="padding: 10px; background-color: #f9f9f9; border-radius: 8px; width: auto; max-width: 60%; color: black;">
                <strong>ValidoAI:</strong> {content}
            </div>
        </div>
        """))

# Funkcija za OpenAI API poziv i prikaz odgovora
def send_message(model, user_message):
    """Komunicira sa OpenAI modelom i prikazuje odgovor."""
    messages = [
        {"role": "system", "content": "Ti si ValidoAI alat za analizu podataka."},
        {"role": "user", "content": user_message}
    ]
    
    # Prikaz korisničke poruke
    display_message("user", user_message)
    
    # API poziv OpenAI modelu
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages
    )
    
    # Prikaz odgovora asistenta
    assistant_message = response['choices'][0]['message']['content']
    display_message("assistant", assistant_message)

# Interaktivni chat sa ipywidgets
def interactive_chat(model):
    """Kreira interaktivni chat sa unosom i dugmetom za slanje."""
    input_box = widgets.Text(
        placeholder="Postavite pitanje vezano za podatke...",
        layout=widgets.Layout(width="80%")  # Proširivanje input polja
    )
    send_button = widgets.Button(
        description="Pošalji",
        button_style="primary",
        tooltip="Kliknite da pošaljete pitanje",
        icon="paper-plane",  # Strelica za slanje
        layout=widgets.Layout(width="15%")  # Manje dugme
    )
    output_area = widgets.Output()

    def on_send_clicked(b):
        user_message = input_box.value.strip()
        if user_message:
            with output_area:
                send_message(model, user_message)
            input_box.value = ""  # Resetovanje input box-a

    send_button.on_click(on_send_clicked)

    # Stilizacija inputa i dugmeta
    input_and_button = widgets.HBox([input_box, send_button], layout=widgets.Layout(
        display="flex",
        justify_content="space-between",
        padding="10px",
        border_radius="8px"
    ))
    
    # Prikaz chat okruženja
    display(widgets.VBox([input_and_button, output_area]))

# Pokretanje chata sa fine-tuned modelom
interactive_chat("ft:gpt-3.5-turbo-1106:robot:domaci-mom21:AkJ2nBnc")
# Out:
# VBox(children=(HBox(children=(Text(value='', layout=Layout(width='80%'), placeholder='Postavite pitanje vezano…
