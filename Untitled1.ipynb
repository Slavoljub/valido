# %%
from scripts.import_kpr import import_kpr
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:postgres@localhost:5432/valido")

import_kpr("uploads/KPR_2025_LOOPING.xlsx", engine)
# Out:
# Učitavam Excel...
# Pravim dobavljače...
# Upisujem račune...
# Upisujem stavke...
# KPR uspešno importovan.
# /home/dev/htdocs/projekat/scripts/import_kpr.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clean["datum"] = pd.to_datetime(df.iloc[:,1], errors="coerce")

# %%
from scripts.import_kpr import import_kpr
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:postgres@localhost:5432/valido")

import_kpr("uploads/KPR_2025_LOOPING.xlsx", engine)
# Out:
# Učitavam Excel...
# Pravim dobavljače...
# Upisujem račune...
# Upisujem stavke...
# KPR uspešno importovan.
# /home/dev/htdocs/projekat/scripts/import_kpr.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clean["datum"] = pd.to_datetime(df.iloc[:,1], errors="coerce")
